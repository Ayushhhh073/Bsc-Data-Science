# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn

# %%
df = pd.read_csv("placement01.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa   iq  placement
# 0           0   6.8  123          1
# 1           1   5.9  106          0
# 2           2   5.3  121          0
# 3           3   7.4  132          1
# 4           4   5.8  142          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    int64
#  3   placement   100 non-null    int64
# dtypes: float64(1), int64(3)
# memory usage: 3.2 KB

# %%
df.describe()
# Out:
#        Unnamed: 0        cgpa          iq   placement
# count  100.000000  100.000000  100.000000  100.000000
# mean    49.500000    5.991000  123.580000    0.500000
# std     29.011492    1.143634   39.944198    0.502519
# min      0.000000    3.300000   37.000000    0.000000
# 25%     24.750000    5.075000  101.500000    0.000000
# 50%     49.500000    6.000000  127.500000    0.500000
# 75%     74.250000    6.900000  149.000000    1.000000
# max     99.000000    8.500000  233.000000    1.000000

# %%
df.shape
# Out:
# (100, 4)

# %% [markdown]
# **Remiving unnamed column**

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa   iq  placement
# 0   6.8  123          1
# 1   5.9  106          0
# 2   5.3  121          0
# 3   7.4  132          1
# 4   5.8  142          0

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'],cmap='viridis')
plt.xlabel('CGPA')
plt.ylabel('IQ')
plt.title('Relationship between CGPA, IQ, and Placement')
plt.show()

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %% [markdown]
# **Instead of above code we can also use**
#
# X = df[['cgpa', 'iq']]   # Select the 'cgpa' and 'iq' columns
#
# y = df['placement']      # Select the 'placement' column

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
X
# Out:
#     cgpa   iq
# 0    6.8  123
# 1    5.9  106
# 2    5.3  121
# 3    7.4  132
# 4    5.8  142
# ..   ...  ...
# 95   4.3  200
# 96   4.4   42
# 97   6.7  182
# 98   6.3  103
# 99   6.2  113
#
# [100 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa   iq
# 43   6.8  141
# 10   6.0   45
# 7    5.0   63
# 91   7.5  158
# 14   6.1  103
# ..   ...  ...
# 75   4.8  169
# 49   5.4  135
# 72   7.3  116
# 94   4.7   52
# 50   3.5  233
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 43    1
# 10    1
# 7     0
# 91    1
# 14    0
#      ..
# 75    0
# 49    0
# 72    1
# 94    0
# 50    0
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa   iq
# 83   7.5  130
# 47   5.2  161
# 37   8.1  149
# 96   4.4   42
# 79   6.5   90
# 81   5.4  107
# 77   7.3   50
# 69   8.5  120
# 2    5.3  121
# 6    5.7  143

# %%
y_test
# Out:
# 83    1
# 47    0
# 37    1
# 96    0
# 79    1
# 81    0
# 77    1
# 69    1
# 2     0
# 6     0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.77101439,  0.40444113],
#        [ 0.0481884 , -2.01380893],
#        [-0.85534409, -1.56038704],
#        [ 1.40348713,  0.83267291],
#        [ 0.13854165, -0.55278285],
#        [ 1.04207414,  0.65634217],
#        [-0.1325181 ,  0.42963123],
#        [ 0.13854165,  0.7822927 ],
#        [ 0.95172089,  1.26090469],
#        [-1.39746358,  0.60596196],
#        [ 0.95172089, -1.53519694],
#        [-1.12640384, -0.95582453],
#        [-0.49393109, -0.2756917 ],
#        [-2.39134932,  1.46242553],
#        [-0.04216485, -0.47721254],
#        [-0.94569734,  0.22811039],
#        [ 0.49995464,  0.12734997],
#        [ 2.12631312,  1.08457395],
#        [ 1.40348713, -1.61076725],
#        [ 0.86136764,  0.35406092],
#        [ 0.86136764,  0.32887081],
#        [-1.03605059, -0.32607191],
#        [ 0.31924815,  0.05177966],
#        [-0.67463759, -0.88025422],
#        [-1.84922983, -0.40164223],
#        [ 0.59030789,  0.32887081],
#        [-0.85534409, -0.85506411],
# ...

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 1.40348713,  0.12734997],
#        [-0.67463759,  0.90824322],
#        [ 1.94560663,  0.60596196],
#        [-1.39746358, -2.08937924],
#        [ 0.49995464, -0.88025422],
#        [-0.49393109, -0.45202244],
#        [ 1.22278064, -1.88785841],
#        [ 2.30701962, -0.12455107],
#        [-0.58428434, -0.09936097],
#        [-0.22287135,  0.45482134]])

# %%
from sklearn.linear_model import LogisticRegression
LogisticRegression
# Out:
# sklearn.linear_model._logistic.LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 83    1
# 47    0
# 37    1
# 96    0
# 79    1
# 81    0
# 77    1
# 69    1
# 2     0
# 6     0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
